# %% [markdown]
# - ## Pitch Type

# %%
# General Packages
import numpy as np
import pandas as pd
import pybaseball as pyb
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 6
#       4 import pandas as pd
#       5 import pybaseball as pyb
# ----> 6 import seaborn as sns
#       8 # Machine Learning
#       9 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pitches2 = pyb.statcast('2021-06-01', '2021-07-01')

print('Our Dataset has {0} Pitches'.format(len(pitches)))
# Out:
# This is a large query, it may take a moment to complete
# 100%|███████████████████████████████████████████| 31/31 [00:07<00:00,  3.93it/s]
# Our Dataset has 500 Pitches

# %%
pitches2['release_speed_rounded'] = round(pitches2['release_speed'])

# %%
pitches
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1617         SL 2021-07-01           88.4          -1.76            5.9
# 1661         SL 2021-07-01           88.8          -1.69           6.01
# 1719         SL 2021-07-01           89.8          -1.62            6.1
# 1739         FF 2021-07-01           97.6           -1.7            5.9
# 1831         FF 2021-07-01           99.3          -1.62           5.93
# ...         ...        ...            ...            ...            ...
# 4001         FF 2021-06-01           92.5           0.59           6.46
# 4142         CH 2021-06-01           84.0            1.0           6.16
# 4300         SL 2021-06-01           86.4           0.58           6.27
# 4438         FF 2021-06-01           90.5           0.59            6.4
# 4563         FF 2021-06-01           90.5           0.73           6.42
#
#             player_name  batter  pitcher     events      description  \
# 1617     Hendriks, Liam  593934   521230  strikeout  swinging_strike
# 1661     Hendriks, Liam  593934   521230        NaN    called_strike
# 1719     Hendriks, Liam  593934   521230        NaN  swinging_strike
# 1739     Hendriks, Liam  593934   521230        NaN             ball
# 1831     Hendriks, Liam  680777   521230     single    hit_into_play
# ...                 ...     ...      ...        ...              ...
# 4001  Zimmermann, Bruce  518626   669145        NaN    called_strike
# 4142  Zimmermann, Bruce  664247   669145  strikeout  swinging_strike
# 4300  Zimmermann, Bruce  664247   669145        NaN             ball
# 4438  Zimmermann, Bruce  664247   669145        NaN             foul
# 4563  Zimmermann, Bruce  664247   669145        NaN    called_strike
#
#       spin_dir  spin_rate_deprecated  break_angle_deprecated  \
# 1617      <NA>                  <NA>                    <NA>
# 1661      <NA>                  <NA>                    <NA>
# 1719      <NA>                  <NA>                    <NA>
# 1739      <NA>                  <NA>                    <NA>
# 1831      <NA>                  <NA>                    <NA>
# ...        ...                   ...                     ...
# 4001      <NA>                  <NA>                    <NA>
# 4142      <NA>                  <NA>                    <NA>
# 4300      <NA>                  <NA>                    <NA>
# 4438      <NA>                  <NA>                    <NA>
# 4563      <NA>                  <NA>                    <NA>
#
#       break_length_deprecated  zone  \
# 1617                     <NA>    14
# 1661                     <NA>     1
# 1719                     <NA>    14
# 1739                     <NA>    11
# 1831                     <NA>     6
# ...                       ...   ...
# 4001                     <NA>    11
# 4142                     <NA>    14
# 4300                     <NA>    13
# 4438                     <NA>     2
# 4563                     <NA>     4
#
#                                                     des game_type stand  \
# 1617                  Miguel Sano strikes out swinging.         R     R
# 1661                  Miguel Sano strikes out swinging.         R     R
# 1719                  Miguel Sano strikes out swinging.         R     R
# 1739                  Miguel Sano strikes out swinging.         R     R
# 1831  Ryan Jeffers singles on a line drive to right ...         R     R
# ...                                                 ...       ...   ...
# 4001               Josh Donaldson strikes out swinging.         R     R
# 4142                 Kyle Garlick strikes out swinging.         R     R
# 4300                 Kyle Garlick strikes out swinging.         R     R
# 4438                 Kyle Garlick strikes out swinging.         R     R
# 4563                 Kyle Garlick strikes out swinging.         R     R
#
#      p_throws home_team away_team type  hit_location     bb_type  balls  \
# 1617        R       CWS       MIN    S             2         NaN      1
# 1661        R       CWS       MIN    S          <NA>         NaN      1
# 1719        R       CWS       MIN    S          <NA>         NaN      1
# 1739        R       CWS       MIN    B          <NA>         NaN      0
# 1831        R       CWS       MIN    X             9  line_drive      3
# ...       ...       ...       ...  ...           ...         ...    ...
# 4001        L       BAL       MIN    S          <NA>         NaN      0
# 4142        L       BAL       MIN    S             2         NaN      1
# 4300        L       BAL       MIN    B          <NA>         NaN      0
# 4438        L       BAL       MIN    S          <NA>         NaN      0
# 4563        L       BAL       MIN    S          <NA>         NaN      0
#
#       strikes  game_year  pfx_x  pfx_z  plate_x  plate_z   on_3b  on_2b  \
# 1617        2       2021   0.11    0.2     0.86     2.16    <NA>   <NA>
# 1661        1       2021   0.08   0.19     -0.3     3.14    <NA>   <NA>
# 1719        0       2021   0.13    0.3     0.98     2.25    <NA>   <NA>
# 1739        0       2021  -0.37   1.57    -0.18     4.56    <NA>   <NA>
# 1831        2       2021  -0.55   1.48     0.64     2.22  663616   <NA>
# ...       ...        ...    ...    ...      ...      ...     ...    ...
# 4001        0       2021   0.71   1.51    -0.85     3.02    <NA>   <NA>
# 4142        2       2021   1.55   0.99     0.37     1.32    <NA>   <NA>
# 4300        2       2021   0.21   0.26     -1.7     0.23    <NA>   <NA>
# 4438        1       2021   0.61   1.47     0.26     2.96    <NA>   <NA>
# 4563        0       2021   0.35    1.6    -0.38     2.36    <NA>   <NA>
#
#        on_1b  outs_when_up  inning inning_topbot   hc_x    hc_y  \
# 1617  680777             2       9           Top   <NA>    <NA>
# 1661  680777             2       9           Top   <NA>    <NA>
# 1719  680777             2       9           Top   <NA>    <NA>
# 1739  680777             2       9           Top   <NA>    <NA>
# 1831    <NA>             2       9           Top  167.6  124.78
# ...      ...           ...     ...           ...    ...     ...
# 4001    <NA>             1       1           Top   <NA>    <NA>
# 4142    <NA>             0       1           Top   <NA>    <NA>
# 4300    <NA>             0       1           Top   <NA>    <NA>
# 4438    <NA>             0       1           Top   <NA>    <NA>
# 4563    <NA>             0       1           Top   <NA>    <NA>
#
#       tfs_deprecated  tfs_zulu_deprecated  fielder_2  umpire  sv_id       vx0  \
# 1617            <NA>                 <NA>     641470    <NA>   <NA>  6.231718
# 1661            <NA>                 <NA>     641470    <NA>   <NA>  3.272469
# 1719            <NA>                 <NA>     641470    <NA>   <NA>  6.246744
# 1739            <NA>                 <NA>     641470    <NA>   <NA>  4.981031
# 1831            <NA>                 <NA>     641470    <NA>   <NA>   7.56052
# ...              ...                  ...        ...     ...    ...       ...
# 4001            <NA>                 <NA>     600474    <NA>   <NA>  -5.19851
# 4142            <NA>                 <NA>     600474    <NA>   <NA> -4.517349
# 4300            <NA>                 <NA>     600474    <NA>   <NA> -5.844714
# 4438            <NA>                 <NA>     600474    <NA>   <NA> -2.131941
# 4563            <NA>                 <NA>     600474    <NA>   <NA> -3.524589
#
#              vy0       vz0         ax         ay         az  sz_top  sz_bot  \
# 1617 -128.753814 -3.568372   0.056698  24.443841 -29.449059    3.55    1.63
# 1661 -129.427847 -1.454418   0.282879  24.069426 -29.950739    3.55    1.64
# 1719 -130.772161 -4.288841    0.32205  25.412431 -28.010663    3.55    1.63
# 1739 -142.050762 -1.732344  -6.086672  32.418863 -10.783516    3.75    1.85
# 1831 -144.349225 -8.339295  -9.392279  30.690142  -9.759708    3.38    1.63
# ...          ...       ...        ...        ...        ...     ...     ...
# 4001  -134.52809 -6.170627   9.732095  31.733823 -12.766903    3.46    1.59
# 4142 -122.009198 -6.695679  16.311446  25.947511 -21.081938    3.41    1.56
# 4300 -125.541541 -8.680395   3.357188  25.058403 -27.900423    3.33    1.61
# 4438 -131.744049 -5.787543   7.549774  27.768425 -14.040437    3.41    1.56
# 4563 -131.661611 -7.585461   4.875184  27.789017 -12.207912    3.43    1.63
#
#       hit_distance_sc  launch_speed  launch_angle  effective_speed  \
# 1617             <NA>          <NA>          <NA>             89.9
# 1661             <NA>          <NA>          <NA>             90.2
# 1719             <NA>          <NA>          <NA>             91.3
# 1739             <NA>          <NA>          <NA>             98.6
# 1831              154          82.2            10            100.8
# ...               ...           ...           ...              ...
# 4001             <NA>          <NA>          <NA>             92.0
# 4142             <NA>          <NA>          <NA>             83.5
# 4300             <NA>          <NA>          <NA>             86.4
# 4438              221          76.5            51             90.5
# 4563             <NA>          <NA>          <NA>             90.4
#
#       release_spin_rate  release_extension  game_pk  pitcher.1  fielder_2.1  \
# 1617               2050                7.0   633529     521230       641470
# 1661               2073                6.8   633529     521230       641470
# 1719               2260                7.0   633529     521230       641470
# 1739               2299                6.8   633529     521230       641470
# 1831               2273                7.0   633529     521230       641470
# ...                 ...                ...      ...        ...          ...
# 4001               2290                6.2   633856     669145       600474
# 4142               2146                6.3   633856     669145       600474
# 4300               2452                6.3   633856     669145       600474
# 4438               2292                6.2   633856     669145       600474
# 4563               2270                6.2   633856     669145       600474
#
#       fielder_3  fielder_4  fielder_5  fielder_6  fielder_7  fielder_8  \
# 1617     518735     664901     544725     641313     571718     571740
# 1661     518735     664901     544725     641313     571718     571740
# 1719     518735     664901     544725     641313     571718     571740
# 1739     518735     664901     544725     641313     571718     571740
# 1831     518735     664901     544725     641313     571718     571740
# ...         ...        ...        ...        ...        ...        ...
# 4001     663624     592859     596748     520471     621466     656775
# 4142     663624     592859     596748     520471     621466     656775
# 4300     663624     592859     596748     520471     621466     656775
# 4438     663624     592859     596748     520471     621466     656775
# 4563     663624     592859     596748     520471     621466     656775
#
#       fielder_9  release_pos_y  estimated_ba_using_speedangle  \
# 1617     657757          53.53                           <NA>
# 1661     657757          53.71                           <NA>
# 1719     657757          53.52                           <NA>
# 1739     657757          53.68                           <NA>
# 1831     657757          53.53                          0.469
# ...         ...            ...                            ...
# 4001     623993           54.3                           <NA>
# 4142     623993          54.23                           <NA>
# 4300     623993          54.17                           <NA>
# 4438     623993          54.27                           <NA>
# 4563     623993          54.28                           <NA>
#
#       estimated_woba_using_speedangle  woba_value  woba_denom  babip_value  \
# 1617                             <NA>         0.0           1            0
# 1661                             <NA>        <NA>        <NA>         <NA>
# 1719                             <NA>        <NA>        <NA>         <NA>
# 1739                             <NA>        <NA>        <NA>         <NA>
# 1831                            0.426         0.9           1            1
# ...                               ...         ...         ...          ...
# 4001                             <NA>        <NA>        <NA>         <NA>
# 4142                             <NA>         0.0           1            0
# 4300                             <NA>        <NA>        <NA>         <NA>
# 4438                             <NA>        <NA>        <NA>         <NA>
# 4563                             <NA>        <NA>        <NA>         <NA>
#
#       iso_value  launch_speed_angle  at_bat_number  pitch_number  \
# 1617          0                <NA>             83             4
# 1661       <NA>                <NA>             83             3
# 1719       <NA>                <NA>             83             2
# 1739       <NA>                <NA>             83             1
# 1831          0                   4             82             7
# ...         ...                 ...            ...           ...
# 4001       <NA>                <NA>              2             1
# 4142          0                <NA>              1             4
# 4300       <NA>                <NA>              1             3
# 4438       <NA>                <NA>              1             2
# 4563       <NA>                <NA>              1             1
#
#            pitch_name  home_score  away_score  bat_score  fld_score  \
# 1617           Slider           8           5          5          8
# 1661           Slider           8           5          5          8
# 1719           Slider           8           5          5          8
# 1739  4-Seam Fastball           8           5          5          8
# 1831  4-Seam Fastball           8           4          4          8
# ...               ...         ...         ...        ...        ...
# 4001  4-Seam Fastball           0           0          0          0
# 4142         Changeup           0           0          0          0
# 4300           Slider           0           0          0          0
# 4438  4-Seam Fastball           0           0          0          0
# 4563  4-Seam Fastball           0           0          0          0
#
#       post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 1617                5                8               5               8
# 1661                5                8               5               8
# 1719                5                8               5               8
# 1739                5                8               5               8
# 1831                5                8               5               8
# ...               ...              ...             ...             ...
# 4001                0                0               0               0
# 4142                0                0               0               0
# 4300                0                0               0               0
# 4438                0                0               0               0
# 4563                0                0               0               0
#
#      if_fielding_alignment of_fielding_alignment  spin_axis  \
# 1617              Standard              Standard        208
# 1661              Standard              Standard        183
# 1719              Standard              Standard        144
# 1739              Standard              Standard        203
# 1831              Standard              Standard        201
# ...                    ...                   ...        ...
# 4001             Strategic              Standard        154
# 4142              Standard              Standard        121
# 4300              Standard              Standard        125
# 4438              Standard              Standard        146
# 4563              Standard              Standard        150
#
#       delta_home_win_exp  delta_run_exp  release_speed_rounded
# 1617               0.011         -0.155                   88.0
# 1661                 0.0         -0.059                   89.0
# 1719                 0.0         -0.048                   90.0
# 1739                 0.0          0.036                   98.0
# 1831              -0.007          0.845                   99.0
# ...                  ...            ...                    ...
# 4001                 0.0         -0.027                   92.0
# 4142               0.022         -0.173                   84.0
# 4300                 0.0          0.022                   86.0
# 4438                 0.0         -0.052                   90.0
# 4563                 0.0         -0.038                   90.0
#
# [119395 rows x 93 columns]

# %%
plot_ = sns.catplot(x='release_speed', y='release_spin_rate', hue='pitch_name', data=pitches[:500])

plt.grid(visible=False)
plt.xlabel('Speed (MPH)')
plt.ylabel('Spin Rate (Revs/Min)')
plt.title('Pitch Type Classification using Speed and Spin Rate')

for ind, label in enumerate(plot_.ax.get_xticklabels()):
    if ind % 20 == 0:  # every 10th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)

# %%
pitches2[ pitches2['p_throws']=='R']
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1647         SL 2021-07-01           88.4          -1.76            5.9
# 1653         SL 2021-07-01           88.8          -1.69           6.01
# 1717         SL 2021-07-01           89.8          -1.62            6.1
# 1759         FF 2021-07-01           97.6           -1.7            5.9
# 1822         FF 2021-07-01           99.3          -1.62           5.93
# ...         ...        ...            ...            ...            ...
# 3990         FF 2021-06-01           90.9          -2.58           6.52
# 4095         SL 2021-06-01           80.3          -2.72           6.61
# 4301         FF 2021-06-01           91.1           -2.6           6.55
# 4400         FF 2021-06-01           90.3          -2.53           6.65
# 4580         FF 2021-06-01           89.7          -2.55           6.57
#
#           player_name  batter  pitcher     events      description  ...  \
# 1647   Hendriks, Liam  593934   521230  strikeout  swinging_strike  ...
# 1653   Hendriks, Liam  593934   521230        NaN    called_strike  ...
# 1717   Hendriks, Liam  593934   521230        NaN  swinging_strike  ...
# 1759   Hendriks, Liam  593934   521230        NaN             ball  ...
# 1822   Hendriks, Liam  680777   521230     single    hit_into_play  ...
# ...               ...     ...      ...        ...              ...  ...
# 3990  Pineda, Michael  641820   501381     single    hit_into_play  ...
# 4095  Pineda, Michael  641820   501381        NaN             foul  ...
# 4301  Pineda, Michael  641820   501381        NaN  swinging_strike  ...
# 4400  Pineda, Michael  656775   501381     triple    hit_into_play  ...
# 4580  Pineda, Michael  656775   501381        NaN    called_strike  ...
#
#       post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 1647                5                8               5               8
# 1653                5                8               5               8
# 1717                5                8               5               8
# 1759                5                8               5               8
# 1822                5                8               5               8
# ...               ...              ...             ...             ...
# 3990                0                1               1               0
# 4095                0                0               0               0
# 4301                0                0               0               0
# 4400                0                0               0               0
# 4580                0                0               0               0
#
#       if_fielding_alignment of_fielding_alignment spin_axis  \
# 1647               Standard              Standard       208
# 1653               Standard              Standard       183
# 1717               Standard              Standard       144
# 1759               Standard              Standard       203
# 1822               Standard              Standard       201
# ...                     ...                   ...       ...
# 3990              Strategic              Standard       224
# 4095               Standard              Standard        41
# 4301               Standard              Standard       221
# 4400               Standard              Standard       211
# 4580               Standard              Standard       223
#
#      delta_home_win_exp delta_run_exp release_speed_rounded
# 1647              0.011        -0.155                  88.0
# 1653                0.0        -0.059                  89.0
# 1717                0.0        -0.048                  90.0
# 1759                0.0         0.036                  98.0
# 1822             -0.007         0.845                  99.0
# ...                 ...           ...                   ...
# 3990              0.044          0.63                  91.0
# 4095                0.0        -0.061                  80.0
# 4301                0.0        -0.067                  91.0
# 4400              0.088          0.93                  90.0
# 4580                0.0        -0.038                  90.0
#
# [83314 rows x 93 columns]

# %%
pitches = pitches2[pitches2['pitch_name']!='Split-Finger']
pitches = pitches[pitches['pitch_name']!='Knuckle Curve']
pitches = pitches[pitches['p_throws']=='R']
pitches = pitches[:500]
print(pitches['pitch_name'].unique())
def pltcolor(lst):
    cols=[]
    for l in pitches['pitch_name']:
        if l=='Slider':
            cols.append('red')
        elif l=='4-Seam Fastball':
            cols.append('blue')
        elif l == 'Changeup':
            cols.append('green')
        elif l == 'Curveball':
            cols.append('orange')
        elif l=='Sinker':
            cols.append('pink')
        elif l == 'Cutter':
            cols.append('brown')
    return cols
# Create the colors list using the function above
cols=pltcolor(pitches['pitch_name'])
# Out:
# ['Slider' '4-Seam Fastball' 'Changeup' 'Curveball' 'Sinker' 'Cutter']

# %%
np.unique(cols)
# Out:
# array(['blue', 'brown', 'green', 'orange', 'pink', 'red'], dtype='<U6')

# %%
len(cols)
# Out:
# 500

# %%
for col,i in enumerate(pitches['pitch_name'].unique()):
        print(col,i)
# Out:
# 0 Slider
# 1 4-Seam Fastball
# 2 Changeup
# 3 Curveball
# 4 Sinker
# 5 Cutter

# %%
# First import everthing you need
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D

# Create a figure and a 3D Axes
fig = plt.figure()
ax = Axes3D(fig)

# Create an init function and the animate functions.
# Both are explained in the tutorial. Since we are changing
# the the elevation and azimuth and no objects are really
# changed on the plot we don't have to return anything from
# the init and animate function. (return value is explained
# in the tutorial.
cols_unique = ['blue', 'brown', 'green', 'orange', 'pink', 'red']
def init():
    
        
    slider = ax.scatter(pitches[pitches['pitch_name']=='Slider']['release_speed'], pitches[pitches['pitch_name']=='Slider']['pfx_x'], pitches[pitches['pitch_name']=='Slider']['pfx_z'], marker='o', s=20, color='orange', alpha=0.6,label='Slider')
    fastball = ax.scatter(pitches[pitches['pitch_name']=='4-Seam Fastball']['release_speed'], pitches[pitches['pitch_name']=='4-Seam Fastball']['pfx_x'], pitches[pitches['pitch_name']=='4-Seam Fastball']['pfx_z'], marker='o', s=20, color='blue', alpha=0.6,label='4-Seam Fastball')
    
    sinker = ax.scatter(pitches[pitches['pitch_name']=='Sinker']['release_speed'], pitches[pitches['pitch_name']=='Sinker']['pfx_x'], pitches[pitches['pitch_name']=='Sinker']['pfx_z'], marker='o', s=20, color='red', alpha=0.6,label='Sinker')
    change = ax.scatter(pitches[pitches['pitch_name']=='Changeup']['release_speed'], pitches[pitches['pitch_name']=='Changeup']['pfx_x'], pitches[pitches['pitch_name']=='Changeup']['pfx_z'], marker='o', s=20, color='brown', alpha=0.6,label='Changeup')
    curve = ax.scatter(pitches[pitches['pitch_name']=='Curveball']['release_speed'], pitches[pitches['pitch_name']=='Curveball']['pfx_x'], pitches[pitches['pitch_name']=='Curveball']['pfx_z'], marker='o', s=20, color='pink', alpha=0.6,label='Curveball')
    cut = ax.scatter(pitches[pitches['pitch_name']=='Cutter']['release_speed'], pitches[pitches['pitch_name']=='Cutter']['pfx_x'], pitches[pitches['pitch_name']=='Cutter']['pfx_z'], marker='o', s=20, color='green', alpha=0.6,label='Cutter')
    ax.legend(handles=[slider,fastball, sinker, change, curve, cut])
    ax.set_xlabel('Speed (MPH)')
    ax.set_ylabel('Horizontal Mov')
    ax.set_zlabel('Vertical Mov')
    return fig,

def animate(i):
    ax.view_init(elev=10., azim=i)
    return fig,

# Animate
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=360, interval=20, blit=True)
# Save
anim.save('speed_x_mov_z_mov.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

# %%
# First import everthing you need
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D

# Create a figure and a 3D Axes
fig = plt.figure()
ax = Axes3D(fig)

# Create an init function and the animate functions.
# Both are explained in the tutorial. Since we are changing
# the the elevation and azimuth and no objects are really
# changed on the plot we don't have to return anything from
# the init and animate function. (return value is explained
# in the tutorial.



def init():
    
    ax.scatter(pitches['vx0'], pitches['vy0'], pitches['vz0'], marker='o', s=20, cmap=pitches['pitch_name'],c=cols, alpha=0.6)
    return fig,

def animate(i):
    ax.view_init(elev=10., azim=i)
    return fig,

# Animate
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=360, interval=20, blit=True)
# Save
anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

# %%
pitches['pitch_name'][:500].unique()
# Out:
# array(['Slider', '4-Seam Fastball', 'Changeup', 'Curveball', 'Sinker',
#        'Cutter'], dtype=object)
